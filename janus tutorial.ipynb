# %%
# Load model directly
from transformers import AutoModel
model = AutoModel.from_pretrained("deepseek-ai/Janus-Pro-7B")
# Out:
# /Users/nover/repos/class/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/repos/class/.venv/lib/python3.9/site-packages/transformers/models/auto/configuration_auto.py:1088, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1087 try:
# -> 1088     config_class = CONFIG_MAPPING[config_dict["model_type"]]
#    1089 except KeyError:
#
# File ~/repos/class/.venv/lib/python3.9/site-packages/transformers/models/auto/configuration_auto.py:790, in _LazyConfigMapping.__getitem__(self, key)
#     789 if key not in self._mapping:
# --> 790     raise KeyError(key)
#     791 value = self._mapping[key]
#
# ...
